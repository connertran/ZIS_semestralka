# %%
import pandas as pd
import numpy as np

TN_cost = 1
FP_cost = 2
FN_cost = 3
TP_cost = 1

cost_matrix = np.array([
    [TN_cost, FP_cost],
    [FN_cost, TP_cost]
])

cost_matrix_df = pd.DataFrame(
    cost_matrix,
    index=["Skutočně Negative", "Skutočně Positive"],
    columns=["Predikované Negative", "Predikované Positive"]
)

display(cost_matrix_df)
# Out:
#                    Predikované Negative  Predikované Positive
# Skutočné Negative                     1                     2
# Skutočné Positive                     3                     1
